# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Analysis of user churn data for a telecom company

# %% [markdown]
# ## Data preparing

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 0            55            19.50    1026.35    Male                0
# 1            72            25.85     1872.2    Male                0
# 2             1            75.90       75.9    Male                0
# 3            32            79.30       2570  Female                1
# 4            60           115.25    6758.45  Female                0
#
#   HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 0        Yes      Yes             Yes                      No
# 1        Yes       No             Yes                     Yes
# 2         No       No             Yes                      No
# 3        Yes       No             Yes                     Yes
# 4        Yes      Yes             Yes                     Yes
#
#   HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 0                 No      No internet service  No internet service
# 1                 No      No internet service  No internet service
# 2        Fiber optic                       No                   No
# 3        Fiber optic                       No                   No
# 4        Fiber optic                      Yes                  Yes
#
#    HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 0  No internet service  No internet service  No internet service
# 1  No internet service  No internet service  No internet service
# 2                   No                  Yes                   No
# 3                  Yes                   No                   No
# 4                  Yes                  Yes                  Yes
#
#   HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 0  No internet service         One year                 No
# 1  No internet service         Two year                 No
# 2                   No   Month-to-month                Yes
# 3                   No   Month-to-month                 No
# 4                  Yes         Two year                 No
#
#              PaymentMethod  Churn
# 0             Mailed check      0
# 1  Credit card (automatic)      0
# 2         Electronic check      1
# 3             Mailed check      0
# 4  Credit card (automatic)      0

# %%
type(df.head())
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.info)
# Out:
# method

# %%
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ClientPeriod              5282 non-null   int64
#  1   MonthlySpending           5282 non-null   float64
#  2   TotalSpent                5282 non-null   object
#  3   Sex                       5282 non-null   object
#  4   IsSeniorCitizen           5282 non-null   int64
#  5   HasPartner                5282 non-null   object
#  6   HasChild                  5282 non-null   object
#  7   HasPhoneService           5282 non-null   object
#  8   HasMultiplePhoneNumbers   5282 non-null   object
#  9   HasInternetService        5282 non-null   object
#  10  HasOnlineSecurityService  5282 non-null   object
#  11  HasOnlineBackup           5282 non-null   object
#  12  HasDeviceProtection       5282 non-null   object
#  13  HasTechSupportAccess      5282 non-null   object
#  14  HasOnlineTV               5282 non-null   object
#  15  HasMovieSubscription      5282 non-null   object
#  16  HasContractPhone          5282 non-null   object
#  17  IsBillingPaperless        5282 non-null   object
#  18  PaymentMethod             5282 non-null   object
#  19  Churn                     5282 non-null   int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 825.4+ KB

# %% [markdown]
# No null values. But TotalSpent has type object which is strange

# %% [markdown]
# #### Little data clearing

# %%
# Find not numbers in TotalSpent
a = {}
for i in range(5282):
    try:
        x = float(df['TotalSpent'][i])
    except:
        a[i] = df['TotalSpent'][i]
a
# Out:
# {1048: ' ',
#  1707: ' ',
#  2543: ' ',
#  3078: ' ',
#  3697: ' ',
#  4002: ' ',
#  4326: ' ',
#  4551: ' ',
#  4598: ' '}

# %%
df.iloc[list(a.keys()), :]
# Out:
#       ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 1048             0            25.75               Male                0
# 1707             0            73.35             Female                0
# 2543             0            19.70               Male                0
# 3078             0            80.85             Female                0
# 3697             0            20.00             Female                0
# 4002             0            61.90               Male                0
# 4326             0            25.35               Male                0
# 4551             0            52.55             Female                0
# 4598             0            56.05             Female                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 1048        Yes      Yes             Yes                     Yes
# 1707        Yes      Yes             Yes                     Yes
# 2543        Yes      Yes             Yes                      No
# 3078        Yes      Yes             Yes                      No
# 3697        Yes      Yes             Yes                      No
# 4002         No      Yes             Yes                     Yes
# 4326        Yes      Yes             Yes                     Yes
# 4551        Yes      Yes              No        No phone service
# 4598        Yes      Yes              No        No phone service
#
#      HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 1048                 No      No internet service  No internet service
# 1707                DSL                       No                  Yes
# 2543                 No      No internet service  No internet service
# 3078                DSL                      Yes                  Yes
# 3697                 No      No internet service  No internet service
# 4002                DSL                      Yes                  Yes
# 4326                 No      No internet service  No internet service
# 4551                DSL                      Yes                   No
# 4598                DSL                      Yes                  Yes
#
#       HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 1048  No internet service  No internet service  No internet service
# 1707                  Yes                  Yes                  Yes
# 2543  No internet service  No internet service  No internet service
# 3078                  Yes                   No                  Yes
# 3697  No internet service  No internet service  No internet service
# 4002                   No                  Yes                   No
# 4326  No internet service  No internet service  No internet service
# 4551                  Yes                  Yes                  Yes
# 4598                  Yes                  Yes                  Yes
#
#      HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 1048  No internet service         Two year                 No
# 1707                   No         Two year                 No
# 2543  No internet service         One year                Yes
# 3078                  Yes         Two year                 No
# 3697  No internet service         Two year                 No
# 4002                   No         Two year                Yes
# 4326  No internet service         Two year                 No
# 4551                   No         Two year                Yes
# 4598                   No         Two year                 No
#
#                   PaymentMethod  Churn
# 1048               Mailed check      0
# 1707               Mailed check      0
# 2543               Mailed check      0
# 3078               Mailed check      0
# 3697               Mailed check      0
# 4002  Bank transfer (automatic)      0
# 4326               Mailed check      0
# 4551  Bank transfer (automatic)      0
# 4598    Credit card (automatic)      0

# %% [markdown]
# All this strings have 0 in ClientPeriod

# %%
sum(df.loc[:, ['ClientPeriod']].values == 0)
# Out:
# array([9])

# %% [markdown]
# And they are the only strings which have 0 in ClientPeriod

# %% [markdown]
# It can be concluded that ' ' in TotalSpent means that TotalSpent is equal 0

# %%
# Change ' ' in TotalSpent to 0
df['TotalSpent'][df['TotalSpent'] == ' '] = 0
df['TotalSpent'] = df['TotalSpent'].astype(float)
# Out:
# <ipython-input-12-bdc7b8e4e4af>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalSpent'][df['TotalSpent'] == ' '] = 0

# %% [markdown]
# #### Transformations

# %%
old = df.copy() #We will need it later

# %% [markdown]
# Look what values categorical columns have

# %%
for col_name in cat_cols:
    print(col_name)
    print(df[col_name].unique())
    print()
# Out:
# Sex
# ['Male' 'Female']
#
# IsSeniorCitizen
# [0 1]
#
# HasPartner
# ['Yes' 'No']
#
# HasChild
# ['Yes' 'No']
#
# HasPhoneService
# ['Yes' 'No']
#
# HasMultiplePhoneNumbers
# ['No' 'Yes' 'No phone service']
#
# HasInternetService
# ['No' 'Fiber optic' 'DSL']
#
# HasOnlineSecurityService
# ['No internet service' 'No' 'Yes']
#
# HasOnlineBackup
# ['No internet service' 'No' 'Yes']
#
# HasDeviceProtection
# ['No internet service' 'No' 'Yes']
#
# HasTechSupportAccess
# ['No internet service' 'Yes' 'No']
#
# HasOnlineTV
# ['No internet service' 'No' 'Yes']
#
# HasMovieSubscription
# ['No internet service' 'No' 'Yes']
#
# HasContractPhone
# ['One year' 'Two year' 'Month-to-month']
#
# IsBillingPaperless
# ['No' 'Yes']
#
# PaymentMethod
# ['Mailed check' 'Credit card (automatic)' 'Electronic check'
#  'Bank transfer (automatic)']

# %% [markdown]
# Most of categorical columns may be reformatted to int64 without loss of data

# %%
yes_or_no_cols = [
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'IsBillingPaperless',
]

# %%
# Make data easier to analyse and use for machine learning
df[yes_or_no_cols] = (df[yes_or_no_cols] == 'Yes').astype(int)
df['Sex'] = (df['Sex'] == 'Male').astype(int)

# %% [markdown]
# Object parameter HasContractPhone can be changed to int64 ContractDuration

# %%
df['HasContractPhone'][df['HasContractPhone'] == 'Month-to-month'] = 0  
df['HasContractPhone'][df['HasContractPhone'] == 'One year'] = 1
df['HasContractPhone'][df['HasContractPhone'] == 'Two year'] = 2
new_columns = list(df.columns)
new_columns[-4] = 'ContractDuration'
df.columns = new_columns
df['ContractDuration'] = df['ContractDuration'].astype(int)
# Out:
# <ipython-input-17-c1b4fa451a64>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HasContractPhone'][df['HasContractPhone'] == 'Month-to-month'] = 0
# <ipython-input-17-c1b4fa451a64>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HasContractPhone'][df['HasContractPhone'] == 'One year'] = 1
# <ipython-input-17-c1b4fa451a64>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HasContractPhone'][df['HasContractPhone'] == 'Two year'] = 2

# %% [markdown]
# Let's create an additional parameter showing how many services of the company every customer uses

# %%
serv = [
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasInternetService',
]

# %%
df[['InternetService']] = df[['HasInternetService']]
df[['HasInternetService']] = (df[['HasInternetService']] != 'No').astype(int)
df['NumberOfServices'] = df[serv].sum(axis=1)
old['NumberOfServices'] = df['NumberOfServices']
num_cols.append('NumberOfServices')

# %%
#Rearrange columns order a bit
cols = df.columns.tolist()
cols = cols[:-3] + cols[-2:]+ cols[-3:-2]
df = df[cols]
df.head()
# Out:
#    ClientPeriod  MonthlySpending  TotalSpent  Sex  IsSeniorCitizen  \
# 0            55            19.50     1026.35    1                0
# 1            72            25.85     1872.20    1                0
# 2             1            75.90       75.90    1                0
# 3            32            79.30     2570.00    0                1
# 4            60           115.25     6758.45    0                0
#
#    HasPartner  HasChild  HasPhoneService  HasMultiplePhoneNumbers  \
# 0           1         1                1                        0
# 1           1         0                1                        1
# 2           0         0                1                        0
# 3           1         0                1                        1
# 4           1         1                1                        1
#
#    HasInternetService  ...  HasDeviceProtection  HasTechSupportAccess  \
# 0                   0  ...                    0                     0
# 1                   0  ...                    0                     0
# 2                   1  ...                    0                     1
# 3                   1  ...                    1                     0
# 4                   1  ...                    1                     1
#
#    HasOnlineTV  HasMovieSubscription  ContractDuration  IsBillingPaperless  \
# 0            0                     0                 1                   0
# 1            0                     0                 2                   0
# 2            0                     0                 0                   1
# 3            0                     0                 0                   0
# 4            1                     1                 2                   0
#
#              PaymentMethod  InternetService NumberOfServices Churn
# 0             Mailed check               No                1     0
# 1  Credit card (automatic)               No                2     0
# 2         Electronic check      Fiber optic                3     1
# 3             Mailed check      Fiber optic                4     0
# 4  Credit card (automatic)      Fiber optic                9     0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ClientPeriod              5282 non-null   int64
#  1   MonthlySpending           5282 non-null   float64
#  2   TotalSpent                5282 non-null   float64
#  3   Sex                       5282 non-null   int64
#  4   IsSeniorCitizen           5282 non-null   int64
#  5   HasPartner                5282 non-null   int64
#  6   HasChild                  5282 non-null   int64
#  7   HasPhoneService           5282 non-null   int64
#  8   HasMultiplePhoneNumbers   5282 non-null   int64
#  9   HasInternetService        5282 non-null   int64
#  10  HasOnlineSecurityService  5282 non-null   int64
#  11  HasOnlineBackup           5282 non-null   int64
#  12  HasDeviceProtection       5282 non-null   int64
#  13  HasTechSupportAccess      5282 non-null   int64
#  14  HasOnlineTV               5282 non-null   int64
#  15  HasMovieSubscription      5282 non-null   int64
#  16  ContractDuration          5282 non-null   int64
#  17  IsBillingPaperless        5282 non-null   int64
#  18  PaymentMethod             5282 non-null   object
#  19  InternetService           5282 non-null   object
#  20  NumberOfServices          5282 non-null   int64
#  21  Churn                     5282 non-null   int64
# dtypes: float64(2), int64(18), object(2)
# memory usage: 908.0+ KB

# %% [markdown]
# Now there is only two object columns. It makes data more convenient for a range of analysis types

# %% [markdown]
# ## Data overview

# %% [markdown]
# Start with representing some information about numeric columns

# %%
df[num_cols].describe()
# Out:
#        ClientPeriod  MonthlySpending   TotalSpent  NumberOfServices
# count   5282.000000      5282.000000  5282.000000       5282.000000
# mean      32.397009        64.924754  2287.486161          4.156191
# std       24.550326        30.176464  2269.049195          2.317374
# min        0.000000        18.250000     0.000000          1.000000
# 25%        9.000000        35.462500   395.725000          2.000000
# 50%       29.000000        70.400000  1405.650000          4.000000
# 75%       55.000000        90.050000  3795.212500          6.000000
# max       72.000000       118.750000  8684.800000          9.000000

# %%
fig, axis = plt.subplots(1, 4, figsize=(20,5))
for i in range(len(num_cols)):
    axis[i].hist(df[num_cols[i]], bins=9)
    axis[i].set_title(num_cols[i])
axis[0].set_ylabel('Number of clients')
# Out:
# Text(0, 0.5, 'Number of clients')

# %% [markdown]
# Then some information about categorical columns

# %%
fig, ax = plt.subplots(4, 4, figsize=(20, 20))
ax = ax.ravel()
for i, cat_col in enumerate(cat_cols):
    ax[i].set_title(cat_col)
    ax[i].pie(old[cat_col].value_counts(), labels=old[cat_col].value_counts().index)
    ax[i].legend()

# %% [markdown]
# And a bit about target column

# %%
fig, ax = plt.subplots()
ax.set_title(target_col)
ax.pie(df[target_col].value_counts(), autopct='%1.1f%%', labels=df[target_col].value_counts().index)
ax.legend()
d = dict(df[target_col].value_counts())
print(f'{d[0]} of customers stayed with firm, {d[1]} left')
# Out:
# 3898 of customers stayed with firm, 1384 left

# %% [markdown]
# ## Data comparison

# %% [markdown]
# Start with pairplot as it gives some general overview about how columns are connected

# %%
fig = sns.pairplot(data=df[num_cols+[target_col]],hue=target_col)

# %% [markdown]
# We can see that in ClientPeriod-MonthlySpending chart blue and orange points are located in different parts, so let's check how relation between ClientPeriod and MonthlySpending depands on whether client left the firm or not

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
sns.boxplot(data=df[df['Churn']==0],x='ClientPeriod', y='MonthlySpending',ax=ax[0])
ax[0].set_title('Stayed')
sns.boxplot(data=df[df['Churn']==1],x='ClientPeriod', y='MonthlySpending',ax=ax[1])
ax[1].set_title('Left the firm')
# Out:
# Text(0.5, 1.0, 'Left the firm')

# %% [markdown]
# It can be concluded that for every value of ClientPeriod MonthlySpendings of those who left the firm were on average noticeably higher than of those who stayed

# %% [markdown]
# The next chart shows this pattern even more clear. Orange and blue lines are parallel, and orange lies 20 points higher. It is a very valuable result

# %%
fig = sns.lmplot(data=df,x='ClientPeriod', y='MonthlySpending',hue='Churn')

# %% [markdown]
# Also we see that, in general, the more ClientPeriod, the more MonthlySpendings

# %% [markdown]
# Now, something about correlation

# %%
fig = df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
fig
# Out:
# <ipython-input-29-b07d9bd8bf7b>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   fig = df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_04af9_row0_col0, #T_04af9_row1_col1, #T_04af9_row2_col2, #T_04af9_row3_col3, #T_04af9_row4_col4, #T_04af9_row5_col5, #T_04af9_row6_col6, #T_04af9_row7_col7, #T_04af9_row8_col8, #T_04af9_row9_col9, #T_04af9_row10_col10, #T_04af9_row11_col11, #T_04af9_row12_col12, #T_04af9_row13_col13, #T_04af9_row14_col14, #T_04af9_row15_col15, #T_04af9_row16_col16, #T_04af9_row17_col17, #T_04af9_row18_col18, #T_04af9_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col1, #T_04af9_row7_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_04af9_row0_col2 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col3, #T_04af9_row2_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col4, #T_04af9_row3_col4, #T_04af9_row3_col6, #T_04af9_row3_col9, #T_04af9_row5_col1, #T_04af9_row10_col14 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col5, #T_04af9_row13_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_04af9_row0_col6, #T_04af9_row11_col14, #T_04af9_row14_col10, #T_04af9_row17_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_04af9_row0_col7, #T_04af9_row14_col6, #T_04af9_row17_col12, #T_04af9_row19_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col8, #T_04af9_row1_col4, #T_04af9_row14_col16 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_04af9_row0_col9, #T_04af9_row6_col10, #T_04af9_row13_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col10, #T_04af9_row1_col17, #T_04af9_row9_col10, #T_04af9_row9_col15 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_04af9_row0_col11, #T_04af9_row1_col19 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_04af9_row0_col12, #T_04af9_row1_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_04af9_row0_col13, #T_04af9_row9_col12, #T_04af9_row17_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_04af9_row0_col14, #T_04af9_row7_col19, #T_04af9_row8_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_04af9_row0_col15, #T_04af9_row15_col17, #T_04af9_row15_col19 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_04af9_row0_col16 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_04af9_row0_col17, #T_04af9_row4_col7, #T_04af9_row4_col15, #T_04af9_row8_col6, #T_04af9_row10_col19 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_04af9_row0_col18, #T_04af9_row1_col11 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_04af9_row0_col19 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_04af9_row1_col0, #T_04af9_row10_col13, #T_04af9_row12_col16, #T_04af9_row15_col12 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_04af9_row1_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_04af9_row1_col3, #T_04af9_row15_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_04af9_row1_col5, #T_04af9_row5_col11, #T_04af9_row6_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_04af9_row1_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_04af9_row1_col7, #T_04af9_row12_col11, #T_04af9_row15_col16 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_04af9_row1_col8, #T_04af9_row12_col9 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_04af9_row1_col9 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_04af9_row1_col12 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_04af9_row1_col13, #T_04af9_row9_col11, #T_04af9_row12_col13, #T_04af9_row12_col15 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_04af9_row1_col14 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_04af9_row1_col15 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_04af9_row1_col16, #T_04af9_row12_col17, #T_04af9_row12_col19, #T_04af9_row14_col5, #T_04af9_row15_col5, #T_04af9_row16_col18 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_04af9_row1_col18 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_04af9_row2_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_04af9_row2_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_04af9_row2_col4, #T_04af9_row8_col12, #T_04af9_row10_col5, #T_04af9_row11_col17, #T_04af9_row17_col18 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_04af9_row2_col5, #T_04af9_row4_col19, #T_04af9_row11_col10, #T_04af9_row16_col13 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_04af9_row2_col6, #T_04af9_row10_col15, #T_04af9_row12_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_04af9_row2_col7, #T_04af9_row5_col13, #T_04af9_row11_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_04af9_row2_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_04af9_row2_col9, #T_04af9_row11_col9, #T_04af9_row13_col0, #T_04af9_row13_col16 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_04af9_row2_col10, #T_04af9_row2_col13 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_04af9_row2_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_04af9_row2_col12, #T_04af9_row8_col2, #T_04af9_row15_col14 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_04af9_row2_col14, #T_04af9_row13_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_04af9_row2_col15 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_04af9_row2_col16, #T_04af9_row15_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_04af9_row2_col17, #T_04af9_row3_col16, #T_04af9_row3_col19, #T_04af9_row8_col15, #T_04af9_row15_col4, #T_04af9_row15_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_04af9_row2_col18 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_04af9_row2_col19, #T_04af9_row4_col18, #T_04af9_row5_col14, #T_04af9_row6_col7, #T_04af9_row10_col17, #T_04af9_row16_col8, #T_04af9_row16_col15 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col0, #T_04af9_row7_col2, #T_04af9_row12_col5, #T_04af9_row14_col4, #T_04af9_row18_col19 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_04af9_row3_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col2, #T_04af9_row13_col17 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col5, #T_04af9_row3_col17, #T_04af9_row7_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col7, #T_04af9_row3_col10, #T_04af9_row4_col5, #T_04af9_row4_col11, #T_04af9_row5_col17 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col8, #T_04af9_row3_col15 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col11, #T_04af9_row6_col9, #T_04af9_row7_col10 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col12, #T_04af9_row6_col17, #T_04af9_row13_col7, #T_04af9_row16_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col13, #T_04af9_row4_col14, #T_04af9_row9_col5, #T_04af9_row14_col7, #T_04af9_row15_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_04af9_row3_col14, #T_04af9_row3_col18, #T_04af9_row6_col18, #T_04af9_row7_col3, #T_04af9_row7_col15, #T_04af9_row9_col3, #T_04af9_row11_col3, #T_04af9_row16_col3, #T_04af9_row19_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_04af9_row4_col0, #T_04af9_row7_col0, #T_04af9_row8_col11, #T_04af9_row17_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_04af9_row4_col1, #T_04af9_row17_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_04af9_row4_col2, #T_04af9_row8_col5, #T_04af9_row8_col10, #T_04af9_row10_col6, #T_04af9_row17_col14 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_04af9_row4_col3, #T_04af9_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_04af9_row4_col6, #T_04af9_row6_col1, #T_04af9_row6_col4, #T_04af9_row6_col8, #T_04af9_row6_col14, #T_04af9_row6_col15, #T_04af9_row7_col12, #T_04af9_row7_col14, #T_04af9_row9_col7, #T_04af9_row10_col3, #T_04af9_row13_col3, #T_04af9_row14_col3, #T_04af9_row16_col9, #T_04af9_row16_col17, #T_04af9_row16_col19, #T_04af9_row17_col3, #T_04af9_row18_col3, #T_04af9_row19_col0, #T_04af9_row19_col2, #T_04af9_row19_col5, #T_04af9_row19_col10, #T_04af9_row19_col11, #T_04af9_row19_col12, #T_04af

# %% [markdown]
# 1) TotalSpent strongly correlate both ClientPeriod and MonthlySpending which is not surprizing at all

# %% [markdown]
# 2) We can assume that clients with larger ClientPeriod tend to have more long-term contracts

# %% [markdown]
# 3) It can be noticed that clients with long ClientPeriod or long-term contract are less likely to leave the firm

# %% [markdown]
# 4) Sex correlate with nothing

# %% [markdown]
# Actually, there is a lot of what can be concluded from this wonderful table, but let's stop here

# %% [markdown]
# The next charts confirms point 2 and partly confirm point 4

# %%
df1 = df[df['Sex']==1]
df2 = df[df['Sex']==0]
cond = [df['ContractDuration']==0, df['ContractDuration']==1, df['ContractDuration']==2]
title = ['Month-to-month', 'One year', 'Two years']

# %%
fig, axis = plt.subplots(1,3, figsize=(20,5))
for j in range(3):
    axis[j].hist([df1[cond[j]]['ClientPeriod'],df2[cond[j]]['ClientPeriod']], bins=9)
    axis[j].legend(['Male','Female'])
    axis[j].set_xlabel('ContractDuration')
    axis[j].set_ylabel('Number of clients')
    axis[j].set_title(title[j])
# Out:
# <ipython-input-43-4ca9d8ce8e7c>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   axis[j].hist([df1[cond[j]]['ClientPeriod'],df2[cond[j]]['ClientPeriod']], bins=9)

# %% [markdown]
# ## Last data comparison

# %% [markdown]
# >Churn has negative correlation with parameters HasOnlineSecurityService, HasOnlineBackup, HasDeviceProtection and HasTechSupportAccess. It is possible to put forward a **hypothesis** that the more serveces client has, the less chance that he leave the firm. Moreover, considering correlation coafficients of Churn with IsSeniorCitizen and HasPartner, we may assume that relatevely young married people even less likely to leave the firm for every value of Number of serveces

# %%
dfss = df[(df['IsSeniorCitizen'] == 1) & (df['HasPartner'] == 0)]
dfsm = df[(df['IsSeniorCitizen'] == 1) & (df['HasPartner'] == 1)]
dfys = df[(df['IsSeniorCitizen'] == 0) & (df['HasPartner'] == 0)]
dfym = df[(df['IsSeniorCitizen'] == 0) & (df['HasPartner'] == 1)]
dss = []
dsm = []
dys = []
dym = []
d = []
for i in range(1,10):
    dfi = dfss[df['NumberOfServices'] == i]['Churn']
    dss.append(sum(list(dfi))/len(dfi))
for i in range(1,10):
    dfi = dfsm[df['NumberOfServices'] == i]['Churn']
    dsm.append(sum(list(dfi))/len(dfi))
for i in range(1,10):
    dfi = dfys[df['NumberOfServices'] == i]['Churn']
    dys.append(sum(list(dfi))/len(dfi))
for i in range(1,10):
    dfi = dfym[df['NumberOfServices'] == i]['Churn']
    dym.append(sum(list(dfi))/len(dfi))
for i in range(1,10):
    dfi = df[df['NumberOfServices'] == i]['Churn']
    d.append(sum(list(dfi))/len(dfi))
# Out:
# <ipython-input-32-5b7d7fded516>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfi = dfss[df['NumberOfServices'] == i]['Churn']
# <ipython-input-32-5b7d7fded516>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfi = dfsm[df['NumberOfServices'] == i]['Churn']
# <ipython-input-32-5b7d7fded516>:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfi = dfys[df['NumberOfServices'] == i]['Churn']
# <ipython-input-32-5b7d7fded516>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfi = dfym[df['NumberOfServices'] == i]['Churn']

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(range(1, 10), dss)
ax.plot(range(1, 10), dsm)
ax.plot(range(1, 10), dys)
ax.plot(range(1, 10), dym)
ax.plot(range(1, 10), d)
ax.set_xlabel('NumberOfServices')
ax.set_ylabel('Churn ratio')
ax.legend(['Senior&Single', 'Senior&Married', 'Young&Single', 'Young&Married', 'All'])

# %% [markdown]
# The hypotesis was partly confirmd. We knew that function showing ratio of left depending on NumberOfServices has form of mountine with pike at 3 purchaced surveces. Young and Married people are actually less likely to leave a firm for every value of NumberOfServices
